# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhilkotian6699/nikhilkotian6699/blob/main/userinputnumber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def arthimatic():
  a= int(input("value for first :"))
  b= int(input("value for sec "))
  return a,b

def add(a,b): #sum
  sum=a+b
  return sum

def sub(a,b):
  sub=a-b
  return sub

def mul(a,b):
  mul=a*b
  return mul

def div(a,b):
  div=a/b
  return div

#main program
a,b = arthimatic()

result= add(a,b)
print("sum of {} and {} is {}".format(a,b,result))
result= sub(a,b)
print("sub of {} and {} is {}".format(a,b,result))
result= mul(a,b)
print("mul of {} and {} is {}".format(a,b,result))
result= div(a,b)
print("div of {} and {} is {}".format(a,b,result))
